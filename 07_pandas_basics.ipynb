# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishra18-hub/Solar-Desalination-ML/blob/main/07_pandas_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# file upload
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-86c5f059-400b-4451-ba2e-7c95a9bc90ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86c5f059-400b-4451-ba2e-7c95a9bc90ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('desalination_data.csv')
print(df)
# Out:
#    Temperature_K  Air_Flow_ms  Solar_Irradiance_Wm2  Ambient_Temperature_K  \
# 0            320            5                   400                    285
# 1            333            8                   600                    290
# 2            345           10                   800                    295
# 3            354           12                  1000                    300
# 4            365           15                  1200                    305
#
#    Droplet_Size_um  Evaporation_Rate_relative  Freshwater_Yield_relative  \
# 0              500                       0.45                       0.40
# 1              300                       0.65                       0.58
# 2              200                       0.82                       0.75
# 3              100                       1.00                       1.00
# 4               50                       1.28                       1.20
#
#    Condensation_Efficiency  Heat_Loss
# ...

# %% [markdown]
# Basic Info

# %%
# Shape
print(f"Shape: {df.shape}")

# Info
df.info()

# Describe
print(df.describe())
# Out:
# Shape: (5, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Temperature_K              5 non-null      int64
#  1   Air_Flow_ms                5 non-null      int64
#  2   Solar_Irradiance_Wm2       5 non-null      int64
#  3   Ambient_Temperature_K      5 non-null      int64
#  4   Droplet_Size_um            5 non-null      int64
#  5   Evaporation_Rate_relative  5 non-null      float64
#  6   Freshwater_Yield_relative  5 non-null      float64
#  7   Condensation_Efficiency    5 non-null      float64
#  8   Heat_Loss                  5 non-null      float64
# dtypes: float64(4), int64(5)
# memory usage: 492.0 bytes
#        Temperature_K  Air_Flow_ms  Solar_Irradiance_Wm2  \
# count       5.000000     5.000000              5.000000
# mean      343.400000    10.000000            800.000000
# ...

# %% [markdown]
# Missing Values

# %%
print(df.isnull().sum())
# Out:
# Temperature_K                0
# Air_Flow_ms                  0
# Solar_Irradiance_Wm2         0
# Ambient_Temperature_K        0
# Droplet_Size_um              0
# Evaporation_Rate_relative    0
# Freshwater_Yield_relative    0
# Condensation_Efficiency      0
# Heat_Loss                    0
# dtype: int64

# %% [markdown]
# Correlations

# %%
print(df.corr())
# Out:
#                            Temperature_K  Air_Flow_ms  Solar_Irradiance_Wm2  \
# Temperature_K                   1.000000     0.996729              0.997937
# Air_Flow_ms                     0.996729     1.000000              0.996546
# Solar_Irradiance_Wm2            0.997937     0.996546              1.000000
# Ambient_Temperature_K           0.997937     0.996546              1.000000
# Droplet_Size_um                -0.982186    -0.972583             -0.972272
# Evaporation_Rate_relative       0.991463     0.997250              0.995342
# Freshwater_Yield_relative       0.991472     0.992617              0.997704
# Condensation_Efficiency        -0.976691    -0.987364             -0.979130
# Heat_Loss                       0.991397     0.996212              0.995893
#
#                            Ambient_Temperature_K  Droplet_Size_um  \
# Temperature_K                           0.997937        -0.982186
# Air_Flow_ms                             0.996546        -0.972583
# ...

# %% [markdown]
# Column Names

# %%
print(df.columns.tolist())
# Out:
# ['Temperature_K', 'Air_Flow_ms', 'Solar_Irradiance_Wm2', 'Ambient_Temperature_K', 'Droplet_Size_um', 'Evaporation_Rate_relative', 'Freshwater_Yield_relative', 'Condensation_Efficiency', 'Heat_Loss']

# %% [markdown]
# Unique Values

# %%
print(df.nunique())
# Out:
# Temperature_K                5
# Air_Flow_ms                  5
# Solar_Irradiance_Wm2         5
# Ambient_Temperature_K        5
# Droplet_Size_um              5
# Evaporation_Rate_relative    5
# Freshwater_Yield_relative    5
# Condensation_Efficiency      5
# Heat_Loss                    5
# dtype: int64

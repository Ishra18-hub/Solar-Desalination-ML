# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishra18-hub/Solar-Desalination-ML/blob/main/01_python_basics_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exercise 1: Variables & Data Types

temperature = 354          # int value and temp. is in kelvin
evaporation_rate = 0.82    # float value
system_name = "Solar Desalination"  # string
is_efficient = True        # boolean

print("=== FYDP Variables ===")
#structure : f"string:{variable}
print(f"Temperature: {temperature} K")
print(f"Evaporation Rate: {evaporation_rate}")
print(f"System: {system_name}")
print(f"Is Efficient? {is_efficient}")

# Practice (value from fydp report)
inlet_temp = 354
outlet_temp = 342
temp_difference = inlet_temp - outlet_temp
print(f"\nTemperature Difference: {temp_difference} K") #\n means new line
# Out:
# === FYDP Variables ===
# Temperature: 354 K
# Evaporation Rate: 0.82
# System: Solar Desalination
# Is Efficient? True
#
# Temperature Difference: 12 K

# %%
# Exercise 2: Lists & Loops

# collected from FYDP's Table 5.21
temperatures = [320, 333, 345, 354, 365]

# temp. and evaporation rate list using for loop
print("==Temperature List==")
for temp in temperatures:
    print(f"Temperature: {temp} K")

evaporation_rates = [0.45, 0.65, 0.82, 1.00, 1.28]

print("\n=== Temperature vs Evaporation Rate ===")
for temp, evap in zip(temperatures, evaporation_rates):
    print(f"{temp} K = {evap} (relative)")
# Out:
# ==Temperature List==
# Temperature: 320 K
# Temperature: 333 K
# Temperature: 345 K
# Temperature: 354 K
# Temperature: 365 K
#
# === Temperature vs Evaporation Rate ===
# 320 K = 0.45 (relative)
# 333 K = 0.65 (relative)
# 345 K = 0.82 (relative)
# 354 K = 1.0 (relative)
# 365 K = 1.28 (relative)

# %%
# Exercise 3: Dictionary

# for observation
observation = {
    "temperature": 354,
    "evaporation_rate": 1.00,
    "freshwater_yield": 1.00,
    "air_flow": 10,
    "solar_irradiance": 1000
}

print("== Observation Data ==")
for key, value in observation.items():
    print(f"{key}: {value}")

# a specific value
print(f"\nFreshwater Yield: {observation['freshwater_yield']}")
# Out:
# == Observation Data ==
# temperature: 354
# evaporation_rate: 1.0
# freshwater_yield: 1.0
# air_flow: 10
# solar_irradiance: 1000
#
# Freshwater Yield: 1.0
